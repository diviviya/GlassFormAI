# %%
# GlassFormAI - Data Understanding

# This notebook explores and validates the metallic glass dataset before machine learning.

# Objectives

# Understand the dataset structure
# Check missing values
# Check duplicates and data quality
# Explore GFA classes
# Examine Dmax, Tg, Tx and Tl
# Identify potential data issues

# Dataset source: Forrest and Greer (2022)
# Out:
#   Cell In[1], line 3
#     This notebook explores and validates the metallic glass dataset before machine learning.
#          ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
import numpy as np

from pathlib import Path

import matplotlib.pyplot as plt
import seaborn as sns

# %%
print("Pandas:", pd.__version__)
print("NumPy:", np.__version__)
# Out:
# Pandas: 3.0.6
# NumPy: 2.5.3

# %%
from pathlib import Path

current_dir = Path.cwd()

possible_paths = [
    current_dir / "data" / "raw" / "data.csv",
    current_dir.parent / "data" / "raw" / "data.csv",
]

DATA_PATH = next(
    (path for path in possible_paths if path.exists()),
    None
)

if DATA_PATH is None:
    raise FileNotFoundError(
        "Could not find data.csv.\n"
        "Expected it at: data/raw/data.csv\n"
        f"Jupyter is currently running from: {current_dir}"
    )

print("Dataset path:", DATA_PATH)
print("Exists:", DATA_PATH.exists())
# Out:
# ../data/raw/data.csv
# Exists: True

# %%
df = pd.read_csv(DATA_PATH)

# %%
df.head()
# Out:
#   composition  Dmax      GFA  Tg  Tx        Tl
# 0       Li100   0.0  Crystal NaN NaN   453.650
# 1       Be100   0.0  Crystal NaN NaN  1560.000
# 2        B100   0.0  Crystal NaN NaN  2349.000
# 3        C100   0.0  Crystal NaN NaN  3800.000
# 4       Na100   0.0  Crystal NaN NaN   370.944

# %%
df.shape
# Out:
# (6637, 6)

# %%
df.columns.tolist()
# Out:
# ['composition', 'Dmax', 'GFA', 'Tg', 'Tx', 'Tl']

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 6637 entries, 0 to 6636
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   composition  6637 non-null   str
#  1   Dmax         6296 non-null   float64
#  2   GFA          6637 non-null   str
#  3   Tg           894 non-null    float64
#  4   Tx           847 non-null    float64
#  5   Tl           1049 non-null   float64
# dtypes: float64(4), str(2)
# memory usage: 311.2 KB
