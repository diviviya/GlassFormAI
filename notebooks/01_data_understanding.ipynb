# %%
# GlassFormAI — Data Understanding & Audit

## Objective

This notebook performs the initial audit of the metallic-glass dataset before
feature engineering and machine-learning model development.

The audit covers:

- Dataset structure and schema
- Missing-value analysis
- Duplicate and composition analysis
- GFA class distribution
- Thermal-property target availability
- Basic statistical distributions
- Composition and elemental coverage
- Potential data-quality issues
- Potential sources of train/test leakage

No machine-learning model is trained in this notebook.

## Dataset

Source:
Forrest, R. M.; Greer, A. L.  
"Machine-learning improves understanding of glass formation in metallic systems."  
Digital Discovery, 2022, 1, 476–489.

DOI: 10.1039/D2DD00026A

The raw dataset is stored locally in:

`../data/raw/data.csv`

# %%
import pandas as pd
import numpy as np

from pathlib import Path

import matplotlib.pyplot as plt
import seaborn as sns

# %%
print("Pandas:", pd.__version__)
print("NumPy:", np.__version__)
# Out:
# Pandas: 3.0.6
# NumPy: 2.5.3

# %%
DATA_PATH = Path("../data/raw/data.csv")

print(DATA_PATH)
print("Exists:", DATA_PATH.exists())
# Out:
# ../data/raw/data.csv
# Exists: True

# %%
df = pd.read_csv(DATA_PATH)

# %%
df.head()
# Out:
#   composition  Dmax      GFA  Tg  Tx        Tl
# 0       Li100   0.0  Crystal NaN NaN   453.650
# 1       Be100   0.0  Crystal NaN NaN  1560.000
# 2        B100   0.0  Crystal NaN NaN  2349.000
# 3        C100   0.0  Crystal NaN NaN  3800.000
# 4       Na100   0.0  Crystal NaN NaN   370.944

# %%
df.shape
# Out:
# (6637, 6)

# %%
df.columns.tolist()
# Out:
# ['composition', 'Dmax', 'GFA', 'Tg', 'Tx', 'Tl']

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 6637 entries, 0 to 6636
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   composition  6637 non-null   str
#  1   Dmax         6296 non-null   float64
#  2   GFA          6637 non-null   str
#  3   Tg           894 non-null    float64
#  4   Tx           847 non-null    float64
#  5   Tl           1049 non-null   float64
# dtypes: float64(4), str(2)
# memory usage: 311.2 KB
